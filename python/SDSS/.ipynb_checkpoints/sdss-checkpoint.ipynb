# %% [markdown]
# # Nessie tutorial:
#
# In this tutorial we will be building a quick group catalog from the Sloan digital sky survey (SDSS).

# %% [markdown]
# ## Download the SDSS data
#
# To do this we will use astroquery and download the galaxies that were used in Tempel+2017 as well as the groups they found them in. This could take a minute or two but feel free to save the file to disk for later use. We also set some survey constants.

# %%
from astroquery.vizier import Vizier

columns = ["GroupID", "Ngal", "zobs", "RAJ2000", "DEJ2000", "rmag"]
vizier = Vizier(columns = columns, row_limit = -1)
sdss_galaxies = vizier.get_catalogs("J/A+A/602/A100/table1")

# These are survey properties that you need to know before hand.
SDSS_MAG_LIM = 17.77
SDSS_FRACTIONAL_AREA = 0.2126803
SDSS_MAX_Z_LIM  = 0.2
B0, R0 = 0.06, 23.8

# %%
import numpy as np
catalog = sdss_galaxies[0]
df = catalog.to_pandas()
df = df[(df['rmag'] < SDSS_MAG_LIM) & (df['zobs'] < SDSS_MAX_Z_LIM)]

ra  = np.array(df['RAJ2000'])
dec = np.array(df['DEJ2000'])
mult = np.array(df['Ngal'])
redshift = np.array(df['zobs'])
mag = np.array(df['rmag'])
tempel_group_id = np.array(df['GroupID'])


import pylab as plt
plt.hist(mag, bins=100)
plt.show()

# %% [markdown]
# # Building the running density from n(z)
#
# The running density might look confusing but `Nessie` will handle building it if you can get a decent approximation of the n(z). This method is a little verbose at the momemnt but future editions of `Nessie` will calculate this automatically from the data itself. In the meantime we have to do a little pre-processing.
#
# ## First order approximation
#
# The very easiest method of approximating the n(z) is to just get it directly from the data itself

# %%
from pylab import plt
import numpy as np

plt.hist(redshift, bins = np.arange(0, 0.22, 0.01), histtype='step', lw=3, color='r')
plt.xlabel("Redshift")
plt.ylabel("Counts")
# Out:
# Text(0, 0.5, 'Counts')

# %% [markdown]
# We can pass this data to `Nessie` to build the density function that we need for group finding using the `create_density_function` helper function which accepts an array of redshifts, the length of the catalog that we are finding groups for (in this case its the same length), the fractional area of the survey, and the cosmology.

# %%
from nessie.helper_funcs import create_density_function
from nessie import FlatCosmology

cosmo = FlatCosmology(0.7, 0.3) # Notice this is NOT an astropy object.
rho_basic = create_density_function(redshift, len(redshift), SDSS_FRACTIONAL_AREA, cosmo)

# %% [markdown]
# This is easy but for real scientific work you'd want to do a better job of getting the n(z) correct although even this basic first start is useful. One could also run a box car over the distribution.
#
#  Slightly more appropriate (but still incomplete) would be to fit a skewed normal to the data and build a distribution from that that we can pass as the n(z).

# %%
from scipy.stats import skewnorm
a_fit, loc_fit, scale_fit = skewnorm.fit(redshift)
MULTIPLE_FACTOR = 10
n_randoms = len(redshift) * MULTIPLE_FACTOR# Make the randoms catalogue 10x the redshift array.
z_randoms = skewnorm.rvs(a=a_fit, loc = loc_fit, scale = scale_fit, size=n_randoms)

plt.hist(redshift, bins = np.arange(0, 0.22, 0.01), histtype='step', lw=3, color='r', density=True, label = 'SDSS n(z)')
plt.hist(z_randoms,  bins = np.arange(0, 0.22, 0.01), histtype='step', lw=3, color='k', density=True, label="Skewed normal n(z)")
plt.legend()
plt.xlabel('Redshift')
plt.ylabel("normalzied counts")
# Out:
# Text(0, 0.5, 'normalzied counts')

# %% [markdown]
# From the plot we can see that the skewed normal has roughly the same shape but doesn't have the same underlying effects from large-scale structure.

# %% [markdown]
# ## More refined modelling of the n(z)
#
# The above methods are easy to implement and give relatively good answers. However, `Nessie` has two helper functions which can be used to generate high-quality modelling of the n(z) which is suitable for publication; either building a randoms catalog follow Farrow et. al., (2015) or doing a parametric fit using Baugh & Efstahiou (1993).
#
# The `create_density_function_be93` works in much the same way as the `create_density_function`, except there is no need to pass the length of the catalog. The randoms method relies on the `gen_random_redshifts` function. It is recommend that these redshifts are run before hand and saved to file. These can then be read in later.

# %%
from nessie.helper_funcs import create_density_function_be93, gen_random_redshifts

# Randoms method:
random_redshifts = gen_random_redshifts(redshift, mag, z_lim = 0.2, maglim = SDSS_MAG_LIM, cosmo = cosmo, n_clone=100)
rho_randoms = create_density_function(random_redshifts, len(redshift), SDSS_FRACTIONAL_AREA, cosmo)
#np.savetxt("randoms.csv", random_redshifts) # You can save to file and simply read in and pass if you want.

# %% [markdown]
# The randoms method has the benefit of producing an n(z) model that can be used for other work.

# %%
plt.hist(redshift, bins = np.arange(0, 0.22, 0.005), histtype='step', lw=3, color='r', density=True, label = 'SDSS n(z)')
plt.hist(z_randoms,  bins = np.arange(0, 0.22, 0.005), histtype='step', lw=3, color='k', density=True, label="Skewed normal n(z)")
plt.hist(random_redshifts, bins = np.arange(0, 0.22, 0.005), histtype='step', lw=3, color='g', density=True, label="Farrow+2015 Randoms Method")
plt.legend()
plt.xlabel('Redshift')
plt.ylabel("normalzied counts")
plt.show()

# %%
# BE+93 method:
rho_be93 = create_density_function_be93(redshift, SDSS_FRACTIONAL_AREA, cosmo)

# %%
rho_skewed = create_density_function(z_randoms, len(z_randoms)/MULTIPLE_FACTOR, SDSS_FRACTIONAL_AREA, cosmo)
rho_randoms = create_density_function(random_redshifts, len(redshift), SDSS_FRACTIONAL_AREA, cosmo)

redshifts = np.linspace(0.05, 0.2, 1000)

plt.plot(redshifts, rho_basic(redshifts), lw=3, color='r', label='Just from data')
plt.plot(redshifts, rho_skewed(redshifts), lw=2, color='k', label='Using skewed normal')
plt.plot(redshifts, rho_randoms(redshifts), lw=3, color='g', label='Farrow+2015 Randoms')
plt.plot(redshifts, rho_be93(redshifts), lw=2, color='m', label='BE+93 fit')
plt.yscale('log')
plt.legend()

# %% [markdown]
# As can be seen from the plot, the randoms method trace the data quite well and provide a smooth function to use. The BE93 method works less well for the particular case of SDSS but is worth using on surveys which are better modeeled by it. See the papers below for more details:
#
# https://arxiv.org/abs/1104.0009
#
# https://ui.adsabs.harvard.edu/abs/2015MNRAS.454.2120F/abstract

# %% [markdown]
# # Running the group finder
#
# Once the density function has been built actually running the group finder on the data becomes a relatively trivial process. If you already know what your linking length constants, b0, and r0 should be.
#
# `Nessie` can calculate the completeness of the survey and adjust linking lengths accordingly using the `calculate_completeness` method if an input catalog is avaialble (the full list of ra and dec of the targets that were targeted). If not then you can assume 100% completeness with the `set_completeness` method without arguments. Or set a constant value to take into account.

# %%
from nessie import RedshiftCatalog

# build the RedshiftCatalog object.
red_cat = RedshiftCatalog(ra, dec, redshift, rho_basic, cosmo)
red_cat.set_completeness() # just assuming 100% completeness for this example.
red_cat.run_fof(b0=B0, r0=R0)

# %% [markdown]
# The python version of `nessie` has tuning capabilities built in to find the optimum set of parameters. B0 and R0 here have been calculated using this method. See the tuning_linking_lengths tutorial.
#
# We do quickly calculate the Figure of Merit score which can be used as a log-likely hood to optimize. Or just map out the full parameter space if you have the time. This would usually be done with a simulation or mock catalog.
#
# In this example we use the score to calculate how well the overlap between the published group catalog (GroupID column) and our restults given the choice of parameters. This highlights how flexible `nessie` is but also how one could improve on the choice of linking lengths.

# %%
# first set the mock group ids (The "true" IDs)

mock_ids = tempel_group_id
mock_ids[mock_ids == 0] = -1 # -1 has to be used as the id of galaxies not found in a group.

red_cat.mock_group_ids = mock_ids
s_total = red_cat.compare_to_mock()
average_overlap = s_total**(1/4)
print("Average overlap with SDSS:", average_overlap)
# Out:
# thread '<unnamed>' panicked at /Users/runner/.cargo/registry/src/index.crates.io-1949cf8c6b5b557f/fof-0.1.14/src/bijectivity.rs:15:5:
# assertion `left == right` failed
#   left: 584449
#  right: 584447
# note: run with `RUST_BACKTRACE=1` environment variable to display a backtrace
# ---------------------------------------------------------------------------
# PanicException                            Traceback (most recent call last)
# Cell In[12], line 7
#       4 mock_ids[mock_ids == 0] = -1 # -1 has to be used as the id of galaxies not found in a group.
#       6 red_cat.mock_group_ids = mock_ids
# ----> 7 s_total = red_cat.compare_to_mock()
#       8 average_overlap = s_total**(1/4)
#       9 print("Average overlap with SDSS:", average_overlap)
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/nessie/catalog.py:250, in RedshiftCatalog.compare_to_mock(self, min_group_size)
#     244     raise ValueError(
# ...

# %% [markdown]
# The s_total score scales in such a way that the average contribution to all four terms is s_total^(1/4) so to get the average overlap one needs to scale appropriately like the above example.
#
# Naturally, the group finder can be run with multiple different values for b0 and r0 in order to find the maximim value of s_total over some parameter space. And the user can do this in any appropriate manner.

# %% [markdown]
# # Getting group properties

# %% [markdown]
# In order to get the full group catalog including all the properties, we need to pass the absolute magnitudes of the survey as well as the velocity errors of the redshifts.
#
# There are many ways to calculate the absolute magnitudes which incldue taking into account various different correction K-correction, K+E correction, SED fitting etc. The user is free to determine the best absolute magnitudes possible.
#
# The simpliest method is just to use the redshifts and the distance modulus which is available in the FlatCosmology object

# %%
absolute_mags = mag - cosmo.dist_mod(redshift)
vel_errs = np.repeat(50, len(absolute_mags)) # just assuming +- 50km/s on the velocity errors.
group_cat = red_cat.calculate_group_table(absolute_mags, vel_errs)

# %% [markdown]
# The group catalog is returned as a dictionary which can easily be converted to something like a Pandas data frame and later saved to file.

# %%
import pandas as pd

group_cat = pd.DataFrame(group_cat)
group_cat

# %% [markdown]
# Additionally a pair cataog can be built too and the group information can be added to the original data frame

# %%
pair_cat = pd.DataFrame(red_cat.calculate_pair_table(absolute_mags))
df['group_id'] = red_cat.group_ids
galaxy_cat = df

pair_cat

# %%
galaxy_cat
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 galaxy_cat
#
# NameError: name 'galaxy_cat' is not defined

# %% [markdown]
# Congrats! You just built the group catalog for SDSS. Too easy.
